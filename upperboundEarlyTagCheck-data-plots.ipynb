# %%
import pandas as pd
import numpy as np
import sys
from matplotlib import pyplot as plt
import os
import statistics

cmap = plt.get_cmap('Set1')

Stats = ['simSeconds ',
'hostSeconds ',
'system.mem_ctrl.readReqs ',
'system.mem_ctrl.writeReqs ',
'system.mem_ctrl.servicedByWrQ ',
'system.mem_ctrl.mergedWrBursts ',
'system.mem_ctrl.numTotHits ',
'system.mem_ctrl.numTotMisses ',
'system.mem_ctrl.numColdMisses ',
'system.mem_ctrl.numHotMisses ',
'system.mem_ctrl.numRdMissClean ',
'system.mem_ctrl.numRdMissDirty ',
'system.mem_ctrl.numRdHit ',
'system.mem_ctrl.numWrMissClean ',
'system.mem_ctrl.numWrMissDirty ',
'system.mem_ctrl.numWrHit ',
'system.mem_ctrl.numRdHitDirty ',
'system.mem_ctrl.numRdHitClean ',
'system.mem_ctrl.numWrHitDirty ',
'system.mem_ctrl.numWrHitClean ',
'system.o3Cpu0.thread_0.numInsts ',
'system.o3Cpu1.thread_0.numInsts ',
'system.o3Cpu2.thread_0.numInsts ',
'system.o3Cpu3.thread_0.numInsts ',
'system.o3Cpu4.thread_0.numInsts ',
'system.o3Cpu5.thread_0.numInsts ',
'system.o3Cpu6.thread_0.numInsts ',
'system.o3Cpu7.thread_0.numInsts ',
'system.mem_ctrl.avgRdBWSys ',
'system.mem_ctrl.avgWrBWSys ',
'system.mem_ctrl.avgORBLen ',
'system.far_mem_ctrl.avgRdBWSys ',
'system.far_mem_ctrl.avgWrBWSys ',
'system.loc_mem_ctrl.avgRdBWSys ',
'system.loc_mem_ctrl.avgWrBWSys ',
'system.loc_mem_ctrl.dram.readBursts ',
'system.loc_mem_ctrl.dram.writeBursts ',
'system.loc_mem_ctrl.dram_2.readBursts ',
'system.loc_mem_ctrl.dram_2.writeBursts ',
'system.far_mem_ctrl.dram.readBursts ',
'system.far_mem_ctrl.dram.writeBursts ',
'system.loc_mem_ctrl.dram.avgRdBW ',
'system.loc_mem_ctrl.dram.avgWrBW ',
'system.loc_mem_ctrl.dram_2.avgRdBW ',
'system.loc_mem_ctrl.dram_2.avgWrBW ',
'system.far_mem_ctrl.dram.avgRdBW ',
'system.far_mem_ctrl.dram.avgWrBW ',
'system.loc_mem_ctrl.dram.busUtil ',
'system.loc_mem_ctrl.dram.busUtilRead ',
'system.loc_mem_ctrl.dram.busUtilWrite ',
'system.loc_mem_ctrl.dram_2.busUtil ',
'system.loc_mem_ctrl.dram_2.busUtilRead ',
'system.loc_mem_ctrl.dram_2.busUtilWrite ',
'system.far_mem_ctrl.dram.busUtil ',
'system.far_mem_ctrl.dram.busUtilRead ',
'system.far_mem_ctrl.dram.busUtilWrite ',
'system.far_mem_ctrl.dram.bytesRead  ',
'system.far_mem_ctrl.dram.bytesWritten  ',
'system.loc_mem_ctrl.dram.bytesRead  ',
'system.loc_mem_ctrl.dram.bytesWritten  ',
'system.loc_mem_ctrl.dram_2.bytesRead  ',
'system.loc_mem_ctrl.dram_2.bytesWritten  ',
'system.mem_ctrl.avgTimeTagCheckRes ',
'system.mem_ctrl.avgTimeTagCheckResRd ',
'system.mem_ctrl.avgTimeTagCheckResWr ',
'system.mem_ctrl.avgPktRespTimeRd ',
'system.mem_ctrl.avgPktRespTimeWr ',
'system.mem_ctrl.avgPktORBTime ',
'system.mem_ctrl.avgPktORBTimeRd ',
'system.mem_ctrl.avgPktORBTimeWr ',
'system.mem_ctrl.avgTimeInLocRead ',
'system.mem_ctrl.avgTimeInLocWrite ',
'system.mem_ctrl.avgTimeInFarRead '
          ]

dfCols = [
         'app',
         'simSeconds',
         'hostSeconds',
         'readReqs',
         'writeReqs',
         'servicedByWrQ',
         'mergedWrBursts',
         'numTotHits',
         'numTotMisses',
         'numColdMisses',
         'numHotMisses',
         'numRdMissClean',
         'numRdMissDirty',
         'numRdHit',
         'numWrMissClean',
         'numWrMissDirty',
         'numWrHit',
         'numRdHitDirty',
         'numRdHitClean',
         'numWrHitDirty',
         'numWrHitClean',
         'numInsts0',
         'numInsts1',
         'numInsts2',
         'numInsts3',
         'numInsts4',
         'numInsts5',
         'numInsts6',
         'numInsts7',
         'avgRdBWSys',
         'avgWrBWSys',
         'avgORBLen',
         'farAvgRdBWSys',
         'farAvgWrBWSys',
         'locAvgRdBWSys',
         'locAvgWrBWSys',
         'readBursts1',
         'writeBursts1',
         'readBursts2',
         'writeBursts2',
         'readBursts3',
         'writeBursts3',
         'loc1AvgRdBW',
         'loc1AvgWrBW',
         'loc2AvgRdBW',
         'loc2AvgWrBW',
         'farAvgRdBW',
         'farAvgWrBW',
         'loc1BusUtil',
         'loc1BusUtilRead',
         'loc1BusUtilWrite',
         'loc2BusUtil',
         'loc2BusUtilRead',
         'loc2BusUtilWrite',
         'farBusUtil',
         'farBusUtilRead',
         'farBusUtilWrite',
         'farBytesRead',
         'farBytesWritten',
         'loc1BytesRead',
         'loc1BytesWritten',
         'loc2BytesRead',
         'loc2BytesWritten',
         'avgTimeTagCheckRes',
         'avgTimeTagCheckResRd',
         'avgTimeTagCheckResWr',
         'avgPktRespTimeRd',
         'avgPktRespTimeWr',
         'avgPktORBTime',
         'avgPktORBTimeRd',
         'avgPktORBTimeWr',
         'avgTimeInLocRead',
         'avgTimeInLocWrite',
         'avgTimeInFarRead'

         ]
##########################################################

def getStat(filename, stat, index):
    filename = os.path.join(filename).replace('\\','/')
    #print(stat)
    #print(filename)
    try:
        x = 0
        with open(filename) as f:
            readlines = f.readlines()
            for l in readlines:
                if stat in l and x < (index-1):
                    x = x+1
                elif stat in l and x == (index-1):
                    return l
            return 0.0 #for cases where stat was not found
    except: #for cases where the file was not found
        return 0.0

##########################################################

def creatDataFrame(dataDir, suite, index):
    app = []
    if suite == "GAPBS":
        app = ['bc', 'bfs', 'cc', 'pr', 'sssp', 'tc']
    if suite == "NPB":
        app = ['bt', 'cg', 'ft', 'is', 'lu', 'mg', 'sp']#, 'ua']
    rows = []
    i = 0
    for a in app:
        stats = [a]
        for stat in Stats:
            time_file_path = '{}/{}/stats.txt'.format(dataDir, a)
            ret_line = getStat(time_file_path, stat, index[i])

            if ret_line != 0:
                #if ret_line=='nan' :
                #    stat_val = 0
                #else:
                stat_val = ret_line.split()[1]
            else:
                stat_val = 0
            stats.append(stat_val)

        rows.append(stats)
        i = i+1
    df = pd.DataFrame(rows, columns= dfCols)
    df['totNumInsts'] = df['numInsts0'].astype(int)+df['numInsts1'].astype(int)+df['numInsts2'].astype(int)+df['numInsts3'].astype(int)+df['numInsts4'].astype(int)+df['numInsts5'].astype(int)+df['numInsts6'].astype(int)+df['numInsts7'].astype(int)
    df['totBW'] = (df['avgRdBWSys'].astype(float)+df['avgWrBWSys'].astype(float))/1000000000
    df['coldRate'] = (df['numColdMisses'].astype(float) / df['numTotMisses'].astype(float)) *100
    df['injRate'] = (df['readReqs'].astype(float) + df['writeReqs'].astype(float))*64/1000000000 / df['simSeconds'].astype(float)
    df['BIPS'] = (df['totNumInsts'].astype(float)/1000000000)/df['simSeconds'].astype(float)
    
    df['accAmp'] =  (df['farBytesRead'].astype(float) + df['farBytesWritten'].astype(float) +
                     df['loc1BytesRead'].astype(float) + df['loc1BytesWritten'].astype(float) + 
                     df['loc2BytesRead'].astype(float) + df['loc2BytesWritten'].astype(float)) / (df['readReqs'].astype(float) * 64 + df['writeReqs'].astype(float) * 64)
    
    df['BWBloat'] =  (df['loc1AvgRdBW'].astype(float) + df['loc1AvgWrBW'].astype(float) +
                      df['loc2AvgRdBW'].astype(float) + df['loc2AvgWrBW'].astype(float) +
                      df['farAvgRdBW'].astype(float) + df['farAvgWrBW'].astype(float)) / ((df['avgRdBWSys'].astype(float) + df['avgWrBWSys'].astype(float)) / 1000000)
    return df

# %%
# df_gap22_dc_1 = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/set-Assoc-Res-Correct2/128MiB_16GB_g22_nC/1/GAPBS", "GAPBS", [1,1,1,1,1,1])
# df_npbC_dc_1 = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/set-Assoc-Res-Correct2/128MiB_16GB_g22_nC/1/NPB", "NPB", [1,1,1,1,1,1,1,1])
df_gap22_dc_2 = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/upperBoundRes/128MiB_16GB_g22_nC/1/GAPBS", "GAPBS", [4,4,3,4,4,12])
df_npbC_dc_2 = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/upperBoundRes/128MiB_16GB_g22_nC/1/NPB", "NPB",[5,4,2,4,3,5,6,0])

# %%
df_gap22_dc_ram = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/analysisRestore/rambus_g22_nC/GAPBS", "GAPBS", [1,1,1,1,1,1])
df_npbC_dc_ram = creatDataFrame("/home/babaie/projects/rambusDesign/x86Fixed/analysisRestore/rambus_g22_nC/NPB", "NPB", [1,1,1,1,1,1,1,1])

# %%
app_gap = df_gap22_dc_ram['app']
gap_1 = df_gap22_dc_ram['simSeconds'].astype(float)*1000
gap_2 = df_gap22_dc_2['simSeconds'].astype(float)*1000

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(8,2)

#plt.ylim([0,55])
for i,app in enumerate(app_gap):
    plt.bar(i*3,   gap_1[i],   width=1, color=cmap(1), label='Baseline' if i==0 else None)
    plt.bar(i*3+1, gap_2[i],   width=1, color=cmap(2), label='Upper-bound' if i==0 else None)

offset = i*3+2
app_npb = df_npbC_dc_ram['app']
npb_1 = df_npbC_dc_ram['simSeconds'].astype(float)*1000
npb_2 = df_npbC_dc_2['simSeconds'].astype(float)*1000

for i,app in enumerate(app_npb): 
    plt.bar(offset+i*3+1,   npb_1[i],     width=1, color=cmap(1))
    plt.bar(offset+i*3+2,   npb_2[i],   width=1, color=cmap(2))

plt.figtext(0.3, 0.01, "GAPBS-22")
plt.figtext(0.75, 0.01, "NPB-C")

plt.xticks(np.arange(13)*3+0.5, list(app_gap)+list(app_npb))
plt.axvline(x=offset, color='black')

plt.ylabel("Execution time (ms)")
plt.legend(fontsize=8, ncol=1)
plt.tight_layout()

print("The geometric mean of execution time of apps in GAPBS")
res = statistics.geometric_mean(gap_1)
print("Baseline:    " + str(res) + " ms")

res = statistics.geometric_mean(gap_2)
print("Upper bound: " + str(res) + " ms")

speedup = gap_1/gap_2
res = statistics.geometric_mean(speedup)
print("Speedup (upper-bound compared to baseline) %: " + str(res))


print("\n\nThe geometric mean of execution time of apps in NPB")
res = statistics.geometric_mean(npb_1)
print("Baseline:    " + str(res) + " ms")

res = statistics.geometric_mean(npb_2)
print("Upper bound: " + str(res) + " ms")

speedup = npb_1/npb_2
res = statistics.geometric_mean(speedup)
print("Speedup (upper-bound compared to baseline) %: " + str(res))
# Out:
# The geometric mean of execution time of apps in GAPBS
# Baseline:    45.99578253958281 ms
# Upper bound: 39.3395640361901 ms
# Speedup (upper-bound compared to baseline) %: 1.1691990917151336
#
#
# The geometric mean of execution time of apps in NPB
# Baseline:    46.75850373243958 ms
# Upper bound: 32.90325412989328 ms
# Speedup (upper-bound compared to baseline) %: 1.4210905568139094

# %%
app_gap = df_gap22_dc_ram['app']
gap_1 = 100 * df_gap22_dc_ram['numTotMisses'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
gap_2 = 100 * df_gap22_dc_2['numTotMisses'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(8,2)

#plt.ylim([0,55])
for i,app in enumerate(app_gap):
    plt.bar(i*3,   gap_1[i],   width=1, color=cmap(1), label='Baseline' if i==0 else None)
    plt.bar(i*3+1, gap_2[i],   width=1, color=cmap(2), label='Upper-bound' if i==0 else None)

offset = i*3+2
app_npb = df_npbC_dc_ram['app']
npb_1 = 100 * df_npbC_dc_ram['numTotMisses'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
npb_2 = 100 * df_npbC_dc_2['numTotMisses'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
for i,app in enumerate(app_npb): 
    plt.bar(offset+i*3+1,   npb_1[i],     width=1, color=cmap(1))
    plt.bar(offset+i*3+2,   npb_2[i],   width=1, color=cmap(2))

plt.figtext(0.3, 0.01, "GAPBS-22")
plt.figtext(0.75, 0.01, "NPB-C")

plt.xticks(np.arange(13)*3+0.5, list(app_gap)+list(app_npb))
plt.axvline(x=offset, color='black')

plt.ylabel("Miss Ratio")
plt.legend(fontsize=8, ncol=1)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_bips.pdf")

# %%
app_gap = df_gap22_dc_ram['app']
gap_1 = 100 * df_gap22_dc_ram['numColdMisses'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
gap_2 = 100 * df_gap22_dc_2['numColdMisses'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(8,2)

plt.ylim([0,100])
for i,app in enumerate(app_gap):
    plt.bar(i*3,   gap_1[i],   width=1, color=cmap(1), label='Baseline' if i==0 else None)
    plt.bar(i*3+1, gap_2[i],   width=1, color=cmap(2), label='Upper-bound' if i==0 else None)

offset = i*3+2
app_npb = df_npbC_dc_ram['app']
npb_1 = 100 * df_npbC_dc_ram['numColdMisses'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
npb_2 = 100 * df_npbC_dc_2['numColdMisses'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
for i,app in enumerate(app_npb): 
    plt.bar(offset+i*3+1,   npb_1[i],     width=1, color=cmap(1))
    plt.bar(offset+i*3+2,   npb_2[i],   width=1, color=cmap(2))

plt.figtext(0.3, 0.01, "GAPBS-22")
plt.figtext(0.75, 0.01, "NPB-C")

plt.xticks(np.arange(13)*3+0.5, list(app_gap)+list(app_npb))
plt.axvline(x=offset, color='black')

plt.ylabel("Cold Misses Ratio")
plt.legend(fontsize=8, ncol=1)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_bips.pdf")

# %%
x1 = df_gap22_dc_ram['app']
y1 = 100 * df_gap22_dc_ram['numRdHitClean'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y2 = 100 * df_gap22_dc_ram['numRdHitDirty'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y3 = 100 * df_gap22_dc_ram['numWrHitClean'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y4 = 100 * df_gap22_dc_ram['numWrHitDirty'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(5,2)
plt.ylim([0,110])

for i,app in enumerate(x1): 
    plt.bar(i*4, y1[i], width=3, color=cmap(1), label='Read/Clean' if i==0 else None)
    plt.bar(i*4, y2[i], bottom = y1[i], width=3, color=cmap(2), label='Read/Dirty' if i==0 else None)
    plt.bar(i*4, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3), label='Write/Clean' if i==0 else None)
    plt.bar(i*4, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4), label='Write/Dirty' if i==0 else None)

offset = (i+1)*4
x2 = df_npbC_dc_ram['app']
y1 = 100 * df_npbC_dc_ram['numRdHitDirty'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y2 = 100 * df_npbC_dc_ram['numRdHitClean'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y3 = 100 * df_npbC_dc_ram['numWrHitDirty'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y4 = 100 * df_npbC_dc_ram['numWrHitClean'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
for i,app in enumerate(x2): 
    plt.bar(i*4+offset, y1[i], width=3, color=cmap(1))
    plt.bar(i*4+offset, y2[i], bottom = y1[i], width=3, color=cmap(2))
    plt.bar(i*4+offset, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3))
    plt.bar(i*4+offset, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4))

plt.figtext(0.3, 0.01, "GAPBS-25")
plt.figtext(0.75, 0.01, "NPB-D")

plt.xticks(np.arange(13)*4, list(x1)+list(x2))
plt.axvline(x=offset-2, color='black')

plt.ylabel("DRAM$  Hits\n per LLC Miss (%)", fontsize=8)
plt.legend(fontsize=7, ncol=1)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_mpki.pdf")




x1 = df_gap22_dc_2['app']
y1 = 100 * df_gap22_dc_2['numRdHitClean'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y2 = 100 * df_gap22_dc_2['numRdHitDirty'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y3 = 100 * df_gap22_dc_2['numWrHitClean'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y4 = 100 * df_gap22_dc_2['numWrHitDirty'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(5,2)
plt.ylim([0,110])

for i,app in enumerate(x1): 
    plt.bar(i*4, y1[i], width=3, color=cmap(1), label='Read/Clean' if i==0 else None)
    plt.bar(i*4, y2[i], bottom = y1[i], width=3, color=cmap(2), label='Read/Dirty' if i==0 else None)
    plt.bar(i*4, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3), label='Write/Clean' if i==0 else None)
    plt.bar(i*4, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4), label='Write/Dirty' if i==0 else None)

offset = (i+1)*4
x2 = df_npbC_dc_2['app']
y1 = 100 * df_npbC_dc_2['numRdHitDirty'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y2 = 100 * df_npbC_dc_2['numRdHitClean'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y3 = 100 * df_npbC_dc_2['numWrHitDirty'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y4 = 100 * df_npbC_dc_2['numWrHitClean'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
for i,app in enumerate(x2): 
    plt.bar(i*4+offset, y1[i], width=3, color=cmap(1))
    plt.bar(i*4+offset, y2[i], bottom = y1[i], width=3, color=cmap(2))
    plt.bar(i*4+offset, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3))
    plt.bar(i*4+offset, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4))

plt.figtext(0.3, 0.01, "GAPBS-25")
plt.figtext(0.75, 0.01, "NPB-D")

plt.xticks(np.arange(13)*4, list(x1)+list(x2))
plt.axvline(x=offset-2, color='black')

plt.ylabel("DRAM$  Hits\n per LLC Miss (%)", fontsize=8)
plt.legend(fontsize=7, ncol=1)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_mpki.pdf")

# %%
x1 = df_gap22_dc_ram['app']
y1 = 100 * df_gap22_dc_ram['numRdMissClean'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y2 = 100 * df_gap22_dc_ram['numRdMissDirty'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y3 = 100 * df_gap22_dc_ram['numWrMissClean'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))
y4 = 100 * df_gap22_dc_ram['numWrMissDirty'].astype(float)/(df_gap22_dc_ram['numTotMisses'].astype(float)+df_gap22_dc_ram['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(5,2)
plt.ylim([0,110])
for i,app in enumerate(x1): 
    plt.bar(i*4, y1[i], width=3, color=cmap(1), label='Read/Clean' if i==0 else None)
    plt.bar(i*4, y2[i], bottom = y1[i], width=3, color=cmap(2), label='Read/Dirty' if i==0 else None)
    plt.bar(i*4, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3), label='Write/Clean' if i==0 else None)
    plt.bar(i*4, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4), label='Write/Dirty' if i==0 else None)

offset = (i+1)*4
x2 = df_npbC_dc_ram['app']
y1 = 100 * df_npbC_dc_ram['numRdMissClean'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y2 = 100 * df_npbC_dc_ram['numRdMissDirty'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y3 = 100 * df_npbC_dc_ram['numWrMissClean'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
y4 = 100 * df_npbC_dc_ram['numWrMissDirty'].astype(float)/(df_npbC_dc_ram['numTotMisses'].astype(float)+df_npbC_dc_ram['numTotHits'].astype(float))
for i,app in enumerate(x2): 
    plt.bar(i*4+offset, y1[i], width=3, color=cmap(1))
    plt.bar(i*4+offset, y2[i], bottom = y1[i], width=3, color=cmap(2))
    plt.bar(i*4+offset, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3))
    plt.bar(i*4+offset, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4))

plt.figtext(0.3, 0.01, "GAPBS-22")
plt.figtext(0.75, 0.01, "NPB-C")

plt.xticks(np.arange(13)*4, list(x1)+list(x2))
plt.axvline(x=offset-2, color='black')

plt.ylabel("DRAM$  Misses\n per LLC Miss (%)", fontsize=8)
plt.legend(fontsize=6, ncol=2)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_mpki.pdf")

x1 = df_gap22_dc_2['app']
y1 = 100 * df_gap22_dc_2['numRdMissClean'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y2 = 100 * df_gap22_dc_2['numRdMissDirty'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y3 = 100 * df_gap22_dc_2['numWrMissClean'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))
y4 = 100 * df_gap22_dc_2['numWrMissDirty'].astype(float)/(df_gap22_dc_2['numTotMisses'].astype(float)+df_gap22_dc_2['numTotHits'].astype(float))

# Multi bar Chart
fig = plt.figure()
fig.set_size_inches(5,2)
plt.ylim([0,110])

for i,app in enumerate(x1): 
    plt.bar(i*4, y1[i], width=3, color=cmap(1), label='Read/Clean' if i==0 else None)
    plt.bar(i*4, y2[i], bottom = y1[i], width=3, color=cmap(2), label='Read/Dirty' if i==0 else None)
    plt.bar(i*4, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3), label='Write/Clean' if i==0 else None)
    plt.bar(i*4, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4), label='Write/Dirty' if i==0 else None)

offset = (i+1)*4
x2 = df_npbC_dc_2['app']
y1 = 100 * df_npbC_dc_2['numRdMissClean'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y2 = 100 * df_npbC_dc_2['numRdMissDirty'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y3 = 100 * df_npbC_dc_2['numWrMissClean'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
y4 = 100 * df_npbC_dc_2['numWrMissDirty'].astype(float)/(df_npbC_dc_2['numTotMisses'].astype(float)+df_npbC_dc_2['numTotHits'].astype(float))
for i,app in enumerate(x2): 
    plt.bar(i*4+offset, y1[i], width=3, color=cmap(1))
    plt.bar(i*4+offset, y2[i], bottom = y1[i], width=3, color=cmap(2))
    plt.bar(i*4+offset, y3[i], bottom = y1[i]+y2[i], width=3, color=cmap(3))
    plt.bar(i*4+offset, y4[i], bottom = y1[i]+y2[i]+y3[i], width=3, color=cmap(4))

plt.figtext(0.3, 0.01, "GAPBS-22")
plt.figtext(0.75, 0.01, "NPB-C")

plt.xticks(np.arange(13)*4, list(x1)+list(x2))
plt.axvline(x=offset-2, color='black')

plt.ylabel("DRAM$  Misses\n per LLC Miss (%)", fontsize=8)
plt.legend(fontsize=6, ncol=2)
plt.tight_layout()
#plt.savefig("../figures/cs1_all_mpki.pdf")
